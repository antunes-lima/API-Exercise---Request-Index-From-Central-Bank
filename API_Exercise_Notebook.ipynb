# %% [markdown]
# # API Exercise Notebook
#
# This notebook will extract historical data of the brazilian National Broad Consumer Price Index (IPCA), an index used to measure the variation of inflation in Brazil. Data will be collected used an API provided by the brazilian Central Bank.

# %%
# importing libraries
import requests
import pandas as pd

# %% [markdown]
# The parameter "**t**" indicates which table we want to request. In this case we want the table nº **1737**, returning the IPCA table.
#
# The parameter "**p**" indicates which period we want to request. In this case we want **all**, returning all months since December 1979, up to July 2022.
#
# The parameter "**v**" indicates which variables we want to request. In this case we want **all**, returning all variables available:
#
#
# *   Index
# *   Monthly variation
# *   3 months cumulative variation
# *   6 months cumulative variation
# *   Year cumulative variation
# *   12 months cumulative variation
#
# The parameter "**n1**" indicates that we want to request national data. On this parameter it would be possible to select specific regions, states or cities.
#
# All these parameters will be added to the base url.

# %%
# parameters
base_url = 'https://apisidra.ibge.gov.br/values'
table = '1737'
period = 'last 12'
variables = 'all'
territory = 'n1/all'

# %% [markdown]
# Concatenating the url and the chosen parameters.

# %%
url = base_url +'/t/'+ table +'/p/'+ period +'/v/'+ variables +'/'+ territory

# %% [markdown]
# Sending the request, and saving the response to the **response** variable.

# %%
response = requests.get( url )

# %% [markdown]
# Requisition status, 2XX would be sucess.

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# Checking response content.

# %%
response.content
# Out:
# b'[\r\n  {\r\n    "NC": "N\xc3\xadvel Territorial (C\xc3\xb3digo)",\r\n    "NN": "N\xc3\xadvel Territorial",\r\n    "MC": "Unidade de Medida (C\xc3\xb3digo)",\r\n    "MN": "Unidade de Medida",\r\n    "V": "Valor",\r\n    "D1C": "M\xc3\xaas (C\xc3\xb3digo)",\r\n    "D1N": "M\xc3\xaas",\r\n    "D2C": "Vari\xc3\xa1vel (C\xc3\xb3digo)",\r\n    "D2N": "Vari\xc3\xa1vel",\r\n    "D3C": "Brasil (C\xc3\xb3digo)",\r\n    "D3N": "Brasil"\r\n  },\r\n  {\r\n    "NC": "1",\r\n    "NN": "Brasil",\r\n    "MC": "30",\r\n    "MN": "N\xc3\xbamero-\xc3\xadndice",\r\n    "V": "5876.0500000000000",\r\n    "D1C": "202108",\r\n    "D1N": "agosto 2021",\r\n    "D2C": "2266",\r\n    "D2N": "IPCA - N\xc3\xbamero-\xc3\xadndice (base: dezembro de 1993 = 100)",\r\n    "D3C": "1",\r\n    "D3N": "Brasil"\r\n  },\r\n  {\r\n    "NC": "1",\r\n    "NN": "Brasil",\r\n    "MC": "2",\r\n    "MN": "%",\r\n    "V": "0.87",\r\n    "D1C": "202108",\r\n    "D1N": "agosto 2021",\r\n    "D2C": "63",\r\n    "D2N": "IPCA - Varia\xc3\xa7\xc3\xa3o mensal",\r\n    "D3C": "1",\r\n    "D3N": "Brasil"\r\n  },\r\n  {\r\n    "NC": "1",\r\n    "NN": "Brasil",\r\n    "MC": "2",\r\n    "MN": "%",\r\n    "V": "2.38",\r\n    "D1C": "202108",\r\n    "D1N": "agosto 2021",\r\n    "D2C": "2263",\r\n    "D2N": "IPCA - Varia\xc3\xa7\xc3\xa3o acumulada em 3 meses",\r\n    "D3C": "1",\r\n    "D3N": "Brasil"\r\n  },\r\n  {\r\n    "NC": "1",\r\n    "NN": "Brasil",\r\n    "MC": "2",\r\n    "MN": "%",\r\n    "V": "4.51",\r\n    "D1C": "202108",\r\n    "D1N": "agosto 2021",\r\n    "D2C": "2264",\r\n    "D2N": "IPCA - Varia\xc3\xa7\xc3\xa3o acumulada em 6 meses",\r\n    "D3C": "1",\r\n    "D3N": "Brasil"\r\n  },\r\n  {\r\n    "NC": "1",\r\n    "NN": "Brasil",\r\n    "MC": "2",\r\n    "MN": "%",\r\n    "V": "5.67",\r\n    "D1C": "202108",\r\n    "D1N": "agosto 2021",\r\n    "D2C": "69",\r\n    "D2N": "IPCA - Varia\xc3\xa7\xc3\xa3o acumulada no ano",\r\n    "D3C": "1",\r\n    "D3N": "Brasil"\r\n  },\r\n  {\r\n    "NC": "1",\r\n    "NN": "Brasil",\r\n    "MC": "2",\r\n    "MN": "%",\r\n    "V": "9.68",\r\n    "D1C": "202108",\r\n    "D1N": "agosto 2021",\r\n    "D2C": "2265",\r\n    "D2N": "IPCA - Varia\xc3\xa7\xc3\xa3o acumulada em 12 meses",\r\n    "D3C": "1",\r\n    "D3N": "Brasil"\r\n  },\r\n  {\r\n    "NC": "1",\r\n    "NN": "Brasil",\r\n    "MC": "30",\r\n    "MN": "N\xc3\xbamero-\xc3\xadndice",\r\n    "V": "5944.2100000000000",\r\n    "D1C": "202109",\r\n    "D1N": "setembro 2021",\r\n    "D2C": "2266",\r\n    "D2N": "IPCA - N\xc3\xbamero-\xc3\xadndice (base: dezembro de 1993 = 100)",\r\n    "D3C": "1",\r\n    "D3N": "Brasil"\r\n  },\r\n  {\r\n    "NC": "1",\r\n    "NN": "Brasil",\r\n    "MC": "2",\r\n    "MN": "%",\r\n    "V": "1.16",\r\n    "D1C": "202109",\r\n    "D1N": "setembro 2021",\r\n    "D2C": "63",\r\n    "D2N": "IPCA - Varia\xc3\xa7\xc3\xa3o mensal",\r\n    "D3C": "1",\r\n    "D3N": "Brasil"\r\n  },\r\n  {\r\n    "NC": "1",\r\n    "NN": "Brasil",\r\n    "MC": "2",\r\n    "MN": "%",\r\n    "V": "3.02",\r\n    "D1C": "202109",\r\n    "D1N": "setembro 2021",\r\n    "D2C": "2263",\r\n    "D2N": "IPCA - Varia\xc3\xa7\xc3\xa3o acumulada em 3 meses",\r\n    "D3C": "1",\r\n    "D3N": "Brasil"\r\n  },\r\n  {\r\n    "NC": "1",\r\n    "NN": "Brasil",\r\n    "MC": "2",\r\n    "MN": "%",\r\n    "V": "4.75",\r\n    "D1C": "202109",\r\n    "D1N": "setembro 2021",\r\n    "D2C": "2264",\r\n    "D2N": "IPCA - Varia\xc3\xa7\xc3\xa3o acumulada em 6 meses",\r\n    "D3C": "1",\r\n    "D3N": "Brasil"\r\n  },\r\n  {\r\n    "NC": "1",\r\n    "NN": "Brasil",\r\n    "MC": "2",\r\n    "MN": "%",\r\n    "V": "6.90",\r\n    "D1C": "202109",\r\n    "D1N": "setembro 2021",\r\n    "D2C": "69",\r\n    "D2N": "IPCA - Varia\xc3\xa7\xc3\xa3o acumulada no ano",\r\n    "D3C": "1",\r\n    "D3N": "Brasil"\r\n  },\r\n  {\r\n    "NC": "1",\r\n    "NN": "Brasil",\r\n    "MC": "2",\r\n    "MN": "%",\r\n    "V": "10.25",\r\n    "D1C": "202109",\r\n    "D1N": "setembro 2021",\r\n    "D2C": "2265",\r\n    "D2N": "IPCA - Varia\xc3\x ...

# %% [markdown]
# Checking response type.

# %%
type( response.content )
# Out:
# bytes

# %% [markdown]
# Checking how it looks using .text command.

# %%
response.text
# Out:
# '[\r\n  {\r\n    "NC": "Nível Territorial (Código)",\r\n    "NN": "Nível Territorial",\r\n    "MC": "Unidade de Medida (Código)",\r\n    "MN": "Unidade de Medida",\r\n    "V": "Valor",\r\n    "D1C": "Mês (Código)",\r\n    "D1N": "Mês",\r\n    "D2C": "Variável (Código)",\r\n    "D2N": "Variável",\r\n    "D3C": "Brasil (Código)",\r\n    "D3N": "Brasil"\r\n  },\r\n  {\r\n    "NC": "1",\r\n    "NN": "Brasil",\r\n    "MC": "30",\r\n    "MN": "Número-índice",\r\n    "V": "5876.0500000000000",\r\n    "D1C": "202108",\r\n    "D1N": "agosto 2021",\r\n    "D2C": "2266",\r\n    "D2N": "IPCA - Número-índice (base: dezembro de 1993 = 100)",\r\n    "D3C": "1",\r\n    "D3N": "Brasil"\r\n  },\r\n  {\r\n    "NC": "1",\r\n    "NN": "Brasil",\r\n    "MC": "2",\r\n    "MN": "%",\r\n    "V": "0.87",\r\n    "D1C": "202108",\r\n    "D1N": "agosto 2021",\r\n    "D2C": "63",\r\n    "D2N": "IPCA - Variação mensal",\r\n    "D3C": "1",\r\n    "D3N": "Brasil"\r\n  },\r\n  {\r\n    "NC": "1",\r\n    "NN": "Brasil",\r\n    "MC": "2",\r\n    "MN": "%",\r\n    "V": "2.38",\r\n    "D1C": "202108",\r\n    "D1N": "agosto 2021",\r\n    "D2C": "2263",\r\n    "D2N": "IPCA - Variação acumulada em 3 meses",\r\n    "D3C": "1",\r\n    "D3N": "Brasil"\r\n  },\r\n  {\r\n    "NC": "1",\r\n    "NN": "Brasil",\r\n    "MC": "2",\r\n    "MN": "%",\r\n    "V": "4.51",\r\n    "D1C": "202108",\r\n    "D1N": "agosto 2021",\r\n    "D2C": "2264",\r\n    "D2N": "IPCA - Variação acumulada em 6 meses",\r\n    "D3C": "1",\r\n    "D3N": "Brasil"\r\n  },\r\n  {\r\n    "NC": "1",\r\n    "NN": "Brasil",\r\n    "MC": "2",\r\n    "MN": "%",\r\n    "V": "5.67",\r\n    "D1C": "202108",\r\n    "D1N": "agosto 2021",\r\n    "D2C": "69",\r\n    "D2N": "IPCA - Variação acumulada no ano",\r\n    "D3C": "1",\r\n    "D3N": "Brasil"\r\n  },\r\n  {\r\n    "NC": "1",\r\n    "NN": "Brasil",\r\n    "MC": "2",\r\n    "MN": "%",\r\n    "V": "9.68",\r\n    "D1C": "202108",\r\n    "D1N": "agosto 2021",\r\n    "D2C": "2265",\r\n    "D2N": "IPCA - Variação acumulada em 12 meses",\r\n    "D3C": "1",\r\n    "D3N": "Brasil"\r\n  },\r\n  {\r\n    "NC": "1",\r\n    "NN": "Brasil",\r\n    "MC": "30",\r\n    "MN": "Número-índice",\r\n    "V": "5944.2100000000000",\r\n    "D1C": "202109",\r\n    "D1N": "setembro 2021",\r\n    "D2C": "2266",\r\n    "D2N": "IPCA - Número-índice (base: dezembro de 1993 = 100)",\r\n    "D3C": "1",\r\n    "D3N": "Brasil"\r\n  },\r\n  {\r\n    "NC": "1",\r\n    "NN": "Brasil",\r\n    "MC": "2",\r\n    "MN": "%",\r\n    "V": "1.16",\r\n    "D1C": "202109",\r\n    "D1N": "setembro 2021",\r\n    "D2C": "63",\r\n    "D2N": "IPCA - Variação mensal",\r\n    "D3C": "1",\r\n    "D3N": "Brasil"\r\n  },\r\n  {\r\n    "NC": "1",\r\n    "NN": "Brasil",\r\n    "MC": "2",\r\n    "MN": "%",\r\n    "V": "3.02",\r\n    "D1C": "202109",\r\n    "D1N": "setembro 2021",\r\n    "D2C": "2263",\r\n    "D2N": "IPCA - Variação acumulada em 3 meses",\r\n    "D3C": "1",\r\n    "D3N": "Brasil"\r\n  },\r\n  {\r\n    "NC": "1",\r\n    "NN": "Brasil",\r\n    "MC": "2",\r\n    "MN": "%",\r\n    "V": "4.75",\r\n    "D1C": "202109",\r\n    "D1N": "setembro 2021",\r\n    "D2C": "2264",\r\n    "D2N": "IPCA - Variação acumulada em 6 meses",\r\n    "D3C": "1",\r\n    "D3N": "Brasil"\r\n  },\r\n  {\r\n    "NC": "1",\r\n    "NN": "Brasil",\r\n    "MC": "2",\r\n    "MN": "%",\r\n    "V": "6.90",\r\n    "D1C": "202109",\r\n    "D1N": "setembro 2021",\r\n    "D2C": "69",\r\n    "D2N": "IPCA - Variação acumulada no ano",\r\n    "D3C": "1",\r\n    "D3N": "Brasil"\r\n  },\r\n  {\r\n    "NC": "1",\r\n    "NN": "Brasil",\r\n    "MC": "2",\r\n    "MN": "%",\r\n    "V": "10.25",\r\n    "D1C": "202109",\r\n    "D1N": "setembro 2021",\r\n    "D2C": "2265",\r\n    "D2N": "IPCA - Variação acumulada em 12 meses",\r\n    "D3C": "1",\r\n    "D3N": "Brasil"\r\n  },\r\n  {\r\n    "NC": "1",\r\n    "NN": "Brasil",\r\n    "MC": "30",\r\n    "MN": "Número-índice",\r\n    "V": "6018.5100000000000",\r\n    "D1C": "202110",\r\n    "D1N": "outubro 2021",\r\n ...

# %% [markdown]
# Checking how it looks as a JSON.

# %%
response.json()
# Out:
# [{'NC': 'Nível Territorial (Código)',
#   'NN': 'Nível Territorial',
#   'MC': 'Unidade de Medida (Código)',
#   'MN': 'Unidade de Medida',
#   'V': 'Valor',
#   'D1C': 'Mês (Código)',
#   'D1N': 'Mês',
#   'D2C': 'Variável (Código)',
#   'D2N': 'Variável',
#   'D3C': 'Brasil (Código)',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '30',
#   'MN': 'Número-índice',
#   'V': '5876.0500000000000',
#   'D1C': '202108',
#   'D1N': 'agosto 2021',
#   'D2C': '2266',
#   'D2N': 'IPCA - Número-índice (base: dezembro de 1993 = 100)',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '2',
#   'MN': '%',
#   'V': '0.87',
#   'D1C': '202108',
#   'D1N': 'agosto 2021',
#   'D2C': '63',
#   'D2N': 'IPCA - Variação mensal',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '2',
#   'MN': '%',
#   'V': '2.38',
#   'D1C': '202108',
#   'D1N': 'agosto 2021',
#   'D2C': '2263',
#   'D2N': 'IPCA - Variação acumulada em 3 meses',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '2',
#   'MN': '%',
#   'V': '4.51',
#   'D1C': '202108',
#   'D1N': 'agosto 2021',
#   'D2C': '2264',
#   'D2N': 'IPCA - Variação acumulada em 6 meses',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '2',
#   'MN': '%',
#   'V': '5.67',
#   'D1C': '202108',
#   'D1N': 'agosto 2021',
#   'D2C': '69',
#   'D2N': 'IPCA - Variação acumulada no ano',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '2',
#   'MN': '%',
#   'V': '9.68',
#   'D1C': '202108',
#   'D1N': 'agosto 2021',
#   'D2C': '2265',
#   'D2N': 'IPCA - Variação acumulada em 12 meses',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '30',
#   'MN': 'Número-índice',
#   'V': '5944.2100000000000',
#   'D1C': '202109',
#   'D1N': 'setembro 2021',
#   'D2C': '2266',
#   'D2N': 'IPCA - Número-índice (base: dezembro de 1993 = 100)',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '2',
#   'MN': '%',
#   'V': '1.16',
#   'D1C': '202109',
#   'D1N': 'setembro 2021',
#   'D2C': '63',
#   'D2N': 'IPCA - Variação mensal',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '2',
#   'MN': '%',
#   'V': '3.02',
#   'D1C': '202109',
#   'D1N': 'setembro 2021',
#   'D2C': '2263',
#   'D2N': 'IPCA - Variação acumulada em 3 meses',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '2',
#   'MN': '%',
#   'V': '4.75',
#   'D1C': '202109',
#   'D1N': 'setembro 2021',
#   'D2C': '2264',
#   'D2N': 'IPCA - Variação acumulada em 6 meses',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '2',
#   'MN': '%',
#   'V': '6.90',
#   'D1C': '202109',
#   'D1N': 'setembro 2021',
#   'D2C': '69',
#   'D2N': 'IPCA - Variação acumulada no ano',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '2',
#   'MN': '%',
#   'V': '10.25',
#   'D1C': '202109',
#   'D1N': 'setembro 2021',
#   'D2C': '2265',
#   'D2N': 'IPCA - Variação acumulada em 12 meses',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '30',
#   'MN': 'Número-índice',
#   'V': '6018.5100000000000',
#   'D1C': '202110',
#   'D1N': 'outubro 2021',
#   'D2C': '2266',
#   'D2N': 'IPCA - Número-índice (base: dezembro de 1993 = 100)',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '2',
#   'MN': '%',
#   'V': '1.25',
#   'D1C': '202110',
#   'D1N': 'outubro 2021',
#   'D2C': '63',
#   'D2N': 'IPCA - Variação mensal',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '2',
#   'MN': '%',
#   'V': '3.32',
#   'D1C': '202110',
#   'D1N': 'outubro 2021',
#   'D2C': '2263',
#   'D2N': 'IPCA - Variação acumulada em 3 meses',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '2',
#   'MN': '%',
#   'V': '5.73',
#   'D1C': '202110',
#   'D1N': 'outubro 2021',
#   'D2C': '2264',
#   'D2N': 'IPCA - Variação acumulada em 6 meses',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '2',
#   'MN': '%',
#   'V': '8.24',
#   'D1C': '202110',
#   'D1N': 'outubro 2021',
#   'D2C': '69',
#   'D2N': 'IPCA - Variação acumulada no ano',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '2',
#   'MN': '%',
#   'V': '10.67',
#   'D1C': '202110',
#   'D1N': 'outubro 2021',
#   'D2C': '2265',
#   'D2N': 'IPCA - Variação acumulada em 12 meses',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '30',
#   'MN': 'Número-índice',
#   'V': '6075.6900000000000',
#   'D1C': '202111',
#   'D1N': 'novembro 2021',
#   'D2C': '2266',
#   'D2N': 'IPCA - Número-índice (base: dezembro de 1993 = 100)',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '2',
#   'MN': '%',
#   'V': '0.95',
#   'D1C': '202111',
#   'D1N': 'novembro 2021',
#   'D2C': '63',
#   'D2N': 'IPCA - Variação mensal',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '2',
#   'MN': '%',
#   'V': '3.40',
#   'D1C': '202111',
#   'D1N': 'novembro 2021',
#   'D2C': '2263',
#   'D2N': 'IPCA - Variação acumulada em 3 meses',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '2',
#   'MN': '%',
#   'V': '5.86',
#   'D1C': '202111',
#   'D1N': 'novembro 2021',
#   'D2C': '2264',
#   'D2N': 'IPCA - Variação acumulada em 6 meses',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '2',
#   'MN': '%',
#   'V': '9.26',
#   'D1C': '202111',
#   'D1N': 'novembro 2021',
#   'D2C': '69',
#   'D2N': 'IPCA - Variação acumulada no ano',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '2',
#   'MN': '%',
#   'V': '10.74',
#   'D1C': '202111',
#   'D1N': 'novembro 2021',
#   'D2C': '2265',
#   'D2N': 'IPCA - Variação acumulada em 12 meses',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '30',
#   'MN': 'Número-índice',
#   'V': '6120.0400000000000',
#   'D1C': '202112',
#   'D1N': 'dezembro 2021',
#   'D2C': '2266',
#   'D2N': 'IPCA - Número-índice (base: dezembro de 1993 = 100)',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '2',
#   'MN': '%',
#   'V': '0.73',
#   'D1C': '202112',
#   'D1N': 'dezembro 2021',
#   'D2C': '63',
#   'D2N': 'IPCA - Variação mensal',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '2',
#   'MN': '%',
#   'V': '2.96',
#   'D1C': '202112',
#   'D1N': 'dezembro 2021',
#   'D2C': '2263',
#   'D2N': 'IPCA - Variação acumulada em 3 meses',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '2',
#   'MN': '%',
#   'V': '6.07',
#   'D1C': '202112',
#   'D1N': 'dezembro 2021',
#   'D2C': '2264',
#   'D2N': 'IPCA - Variação acumulada em 6 meses',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '2',
#   'MN': '%',
#   'V': '10.06',
#   'D1C': '202112',
#   'D1N': 'dezembro 2021',
#   'D2C': '69',
#   'D2N': 'IPCA - Variação acumulada no ano',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '2',
#   'MN': '%',
#   'V': '10.06',
#   'D1C': '202112',
#   'D1N': 'dezembro 2021',
#   'D2C': '2265',
#   'D2N': 'IPCA - Variação acumulada em 12 meses',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '30',
#   'MN': 'Número-índice',
#   'V': '6153.0900000000000',
#   'D1C': '202201',
#   'D1N': 'janeiro 2022',
#   'D2C': '2266',
#   'D2N': 'IPCA - Número-índice (base: dezembro de 1993 = 100)',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '2',
#   'MN': '%',
#   'V': '0.54',
#   'D1C': '202201',
#   'D1N': 'janeiro 2022',
#   'D2C': '63',
#   'D2N': 'IPCA - Variação mensal',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '2',
#   'MN': '%',
#   'V': '2.24',
#   'D1C': '202201',
#   'D1N': 'janeiro 2022',
#   'D2C': '2263',
#   'D2N': 'IPCA - Variação acumulada em 3 meses',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '2',
#   'MN': '%',
#   'V': '5.63',
#   'D1C': '202201',
#   'D1N': 'janeiro 2022',
#   'D2C': '2264',
#   'D2N': 'IPCA - Variação acumulada em 6 meses',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '2',
#   'MN': '%',
#   'V': '0.54',
#   'D1C': '202201',
#   'D1N': 'janeiro 2022',
#   'D2C': '69',
#   'D2N': 'IPCA - Variação acumulada no ano',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '2',
#   'MN': '%',
#   'V': '10.38',
#   'D1C': '202201',
#   'D1N': 'janeiro 2022',
#   'D2C': '2265',
#   'D2N': 'IPCA - Variação acumulada em 12 meses',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '30',
#   'MN': 'Número-índice',
#   'V': '6215.2400000000000',
#   'D1C': '202202',
#   'D1N': 'fevereiro 2022',
#   'D2C': '2266',
#   'D2N': 'IPCA - Número-índice (base: dezembro de 1993 = 100)',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '2',
#   'MN': '%',
#   'V': '1.01',
#   'D1C': '202202',
#   'D1N': 'fevereiro 2022',
#   'D2C': '63',
#   'D2N': 'IPCA - Variação mensal',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '2',
#   'MN': '%',
#   'V': '2.30',
#   'D1C': '202202',
#   'D1N': 'fevereiro 2022',
#   'D2C': '2263',
#   'D2N': 'IPCA - Variação acumulada em 3 meses',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '2',
#   'MN': '%',
#   'V': '5.77',
#   'D1C': '202202',
#   'D1N': 'fevereiro 2022',
#   'D2C': '2264',
#   'D2N': 'IPCA - Variação acumulada em 6 meses',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '2',
#   'MN': '%',
#   'V': '1.56',
#   'D1C': '202202',
#   'D1N': 'fevereiro 2022',
#   'D2C': '69',
#   'D2N': 'IPCA - Variação acumulada no ano',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '2',
#   'MN': '%',
#   'V': '10.54',
#   'D1C': '202202',
#   'D1N': 'fevereiro 2022',
#   'D2C': '2265',
#   'D2N': 'IPCA - Variação acumulada em 12 meses',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '30',
#   'MN': 'Número-índice',
#   'V': '6315.9300000000000',
#   'D1C': '202203',
#   'D1N': 'março 2022',
#   'D2C': '2266',
#   'D2N': 'IPCA - Número-índice (base: dezembro de 1993 = 100)',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '2',
#   'MN': '%',
#   'V': '1.62',
#   'D1C': '202203',
#   'D1N': 'março 2022',
#   'D2C': '63',
#   'D2N': 'IPCA - Variação mensal',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '2',
#   'MN': '%',
#   'V': '3.20',
#   'D1C': '202203',
#   'D1N': 'março 2022',
#   'D2C': '2263',
#   'D2N': 'IPCA - Variação acumulada em 3 meses',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '2',
#   'MN': '%',
#   'V': '6.25',
#   'D1C': '202203',
#   'D1N': 'março 2022',
#   'D2C': '2264',
#   'D2N': 'IPCA - Variação acumulada em 6 meses',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '2',
#   'MN': '%',
#   'V': '3.20',
#   'D1C': '202203',
#   'D1N': 'março 2022',
#   'D2C': '69',
#   'D2N': 'IPCA - Variação acumulada no ano',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '2',
#   'MN': '%',
#   'V': '11.30',
#   'D1C': '202203',
#   'D1N': 'março 2022',
#   'D2C': '2265',
#   'D2N': 'IPCA - Variação acumulada em 12 meses',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '30',
#   'MN': 'Número-índice',
#   'V': '6382.8800000000000',
#   'D1C': '202204',
#   'D1N': 'abril 2022',
#   'D2C': '2266',
#   'D2N': 'IPCA - Número-índice (base: dezembro de 1993 = 100)',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '2',
#   'MN': '%',
#   'V': '1.06',
#   'D1C': '202204',
#   'D1N': 'abril 2022',
#   'D2C': '63',
#   'D2N': 'IPCA - Variação mensal',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '2',
#   'MN': '%',
#   'V': '3.73',
#   'D1C': '202204',
#   'D1N': 'abril 2022',
#   'D2C': '2263',
#   'D2N': 'IPCA - Variação acumulada em 3 meses',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '2',
#   'MN': '%',
#   'V': '6.05',
#   'D1C': '202204',
#   'D1N': 'abril 2022',
#   'D2C': '2264',
#   'D2N': 'IPCA - Variação acumulada em 6 meses',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '2',
#   'MN': '%',
#   'V': '4.29',
#   'D1C': '202204',
#   'D1N': 'abril 2022',
#   'D2C': '69',
#   'D2N': 'IPCA - Variação acumulada no ano',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '2',
#   'MN': '%',
#   'V': '12.13',
#   'D1C': '202204',
#   'D1N': 'abril 2022',
#   'D2C': '2265',
#   'D2N': 'IPCA - Variação acumulada em 12 meses',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '30',
#   'MN': 'Número-índice',
#   'V': '6412.8800000000000',
#   'D1C': '202205',
#   'D1N': 'maio 2022',
#   'D2C': '2266',
#   'D2N': 'IPCA - Número-índice (base: dezembro de 1993 = 100)',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '2',
#   'MN': '%',
#   'V': '0.47',
#   'D1C': '202205',
#   'D1N': 'maio 2022',
#   'D2C': '63',
#   'D2N': 'IPCA - Variação mensal',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '2',
#   'MN': '%',
#   'V': '3.18',
#   'D1C': '202205',
#   'D1N': 'maio 2022',
#   'D2C': '2263',
#   'D2N': 'IPCA - Variação acumulada em 3 meses',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '2',
#   'MN': '%',
#   'V': '5.55',
#   'D1C': '202205',
#   'D1N': 'maio 2022',
#   'D2C': '2264',
#   'D2N': 'IPCA - Variação acumulada em 6 meses',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '2',
#   'MN': '%',
#   'V': '4.78',
#   'D1C': '202205',
#   'D1N': 'maio 2022',
#   'D2C': '69',
#   'D2N': 'IPCA - Variação acumulada no ano',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '2',
#   'MN': '%',
#   'V': '11.73',
#   'D1C': '202205',
#   'D1N': 'maio 2022',
#   'D2C': '2265',
#   'D2N': 'IPCA - Variação acumulada em 12 meses',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '30',
#   'MN': 'Número-índice',
#   'V': '6455.8500000000000',
#   'D1C': '202206',
#   'D1N': 'junho 2022',
#   'D2C': '2266',
#   'D2N': 'IPCA - Número-índice (base: dezembro de 1993 = 100)',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '2',
#   'MN': '%',
#   'V': '0.67',
#   'D1C': '202206',
#   'D1N': 'junho 2022',
#   'D2C': '63',
#   'D2N': 'IPCA - Variação mensal',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '2',
#   'MN': '%',
#   'V': '2.22',
#   'D1C': '202206',
#   'D1N': 'junho 2022',
#   'D2C': '2263',
#   'D2N': 'IPCA - Variação acumulada em 3 meses',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '2',
#   'MN': '%',
#   'V': '5.49',
#   'D1C': '202206',
#   'D1N': 'junho 2022',
#   'D2C': '2264',
#   'D2N': 'IPCA - Variação acumulada em 6 meses',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '2',
#   'MN': '%',
#   'V': '5.49',
#   'D1C': '202206',
#   'D1N': 'junho 2022',
#   'D2C': '69',
#   'D2N': 'IPCA - Variação acumulada no ano',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '2',
#   'MN': '%',
#   'V': '11.89',
#   'D1C': '202206',
#   'D1N': 'junho 2022',
#   'D2C': '2265',
#   'D2N': 'IPCA - Variação acumulada em 12 meses',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '30',
#   'MN': 'Número-índice',
#   'V': '6411.9500000000000',
#   'D1C': '202207',
#   'D1N': 'julho 2022',
#   'D2C': '2266',
#   'D2N': 'IPCA - Número-índice (base: dezembro de 1993 = 100)',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '2',
#   'MN': '%',
#   'V': '-0.68',
#   'D1C': '202207',
#   'D1N': 'julho 2022',
#   'D2C': '63',
#   'D2N': 'IPCA - Variação mensal',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '2',
#   'MN': '%',
#   'V': '0.46',
#   'D1C': '202207',
#   'D1N': 'julho 2022',
#   'D2C': '2263',
#   'D2N': 'IPCA - Variação acumulada em 3 meses',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '2',
#   'MN': '%',
#   'V': '4.21',
#   'D1C': '202207',
#   'D1N': 'julho 2022',
#   'D2C': '2264',
#   'D2N': 'IPCA - Variação acumulada em 6 meses',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '2',
#   'MN': '%',
#   'V': '4.77',
#   'D1C': '202207',
#   'D1N': 'julho 2022',
#   'D2C': '69',
#   'D2N': 'IPCA - Variação acumulada no ano',
#   'D3C': '1',
#   'D3N': 'Brasil'},
#  {'NC': '1',
#   'NN': 'Brasil',
#   'MC': '2',
#   'MN': '%',
#   'V': '10.07',
#   'D1C': '202207',
#   'D1N': 'julho 2022',
#   'D2C': '2265',
#   'D2N': 'IPCA - Variação acumulada em 12 meses',
#   'D3C': '1',
#   'D3N': 'Brasil'}]

# %%
type( response.json() )
# Out:
# list

# %% [markdown]
# Converting it to a **DataFrame**.

# %%
df = pd.DataFrame( response.json() )

# %%
df.head()
# Out:
#                            NC                 NN                          MC  \
# 0  Nível Territorial (Código)  Nível Territorial  Unidade de Medida (Código)
# 1                           1             Brasil                          30
# 2                           1             Brasil                           2
# 3                           1             Brasil                           2
# 4                           1             Brasil                           2
#
#                   MN                   V           D1C          D1N  \
# 0  Unidade de Medida               Valor  Mês (Código)          Mês
# 1      Número-índice  5876.0500000000000        202108  agosto 2021
# 2                  %                0.87        202108  agosto 2021
# 3                  %                2.38        202108  agosto 2021
# 4                  %                4.51        202108  agosto 2021
#
#                  D2C                                                D2N  \
# 0  Variável (Código)                                           Variável
# 1               2266  IPCA - Número-índice (base: dezembro de 1993 =...
# 2                 63                             IPCA - Variação mensal
# 3               2263               IPCA - Variação acumulada em 3 meses
# 4               2264               IPCA - Variação acumulada em 6 meses
#
#                D3C     D3N
# 0  Brasil (Código)  Brasil
# 1                1  Brasil
# 2                1  Brasil
# 3                1  Brasil
# 4                1  Brasil

# %%
df.shape
# Out:
# (73, 11)

# %% [markdown]
# Chosing a specific variable (we collected all at the beginning), to check if it has correctly selected the last 12 months values.

# %%
df.loc[ df['D2C'] == '2266' ]
# Out:
#    NC      NN  MC             MN                   V     D1C             D1N  \
# 1   1  Brasil  30  Número-índice  5876.0500000000000  202108     agosto 2021
# 7   1  Brasil  30  Número-índice  5944.2100000000000  202109   setembro 2021
# 13  1  Brasil  30  Número-índice  6018.5100000000000  202110    outubro 2021
# 19  1  Brasil  30  Número-índice  6075.6900000000000  202111   novembro 2021
# 25  1  Brasil  30  Número-índice  6120.0400000000000  202112   dezembro 2021
# 31  1  Brasil  30  Número-índice  6153.0900000000000  202201    janeiro 2022
# 37  1  Brasil  30  Número-índice  6215.2400000000000  202202  fevereiro 2022
# 43  1  Brasil  30  Número-índice  6315.9300000000000  202203      março 2022
# 49  1  Brasil  30  Número-índice  6382.8800000000000  202204      abril 2022
# 55  1  Brasil  30  Número-índice  6412.8800000000000  202205       maio 2022
# 61  1  Brasil  30  Número-índice  6455.8500000000000  202206      junho 2022
# 67  1  Brasil  30  Número-índice  6411.9500000000000  202207      julho 2022
#
#      D2C                                                D2N D3C     D3N
# 1   2266  IPCA - Número-índice (base: dezembro de 1993 =...   1  Brasil
# 7   2266  IPCA - Número-índice (base: dezembro de 1993 =...   1  Brasil
# 13  2266  IPCA - Número-índice (base: dezembro de 1993 =...   1  Brasil
# 19  2266  IPCA - Número-índice (base: dezembro de 1993 =...   1  Brasil
# 25  2266  IPCA - Número-índice (base: dezembro de 1993 =...   1  Brasil
# 31  2266  IPCA - Número-índice (base: dezembro de 1993 =...   1  Brasil
# 37  2266  IPCA - Número-índice (base: dezembro de 1993 =...   1  Brasil
# 43  2266  IPCA - Número-índice (base: dezembro de 1993 =...   1  Brasil
# 49  2266  IPCA - Número-índice (base: dezembro de 1993 =...   1  Brasil
# 55  2266  IPCA - Número-índice (base: dezembro de 1993 =...   1  Brasil
# 61  2266  IPCA - Número-índice (base: dezembro de 1993 =...   1  Brasil
# 67  2266  IPCA - Número-índice (base: dezembro de 1993 =...   1  Brasil

# %%
df.loc[ df['D2C'] == '2266' ].shape
# Out:
# (12, 11)
